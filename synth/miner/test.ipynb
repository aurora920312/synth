# %%
from datetime import datetime

from pydantic import BaseModel, Field

class SimulationInput(BaseModel):
    asset: str = Field(default="BTC", description="The asset to simulate.")
    start_time: str = Field(
        default=datetime.now().isoformat(),
        description="The start time of the simulation.",
    )
    time_increment: int = Field(
        default=300, description="Time increment in seconds."
    )
    time_length: int = Field(
        default=86400, description="Total time length in seconds."
    )
    num_simulations: int = Field(
        default=1, description="Number of simulation runs."
    )

    class Config:
        arbitrary_types_allowed = True

# %%
simulation_input = SimulationInput(
        asset="BTC",
        time_increment=300,
        time_length=86400,
        num_simulations=3,
    )

# %%
from datetime import timedelta, timezone
def get_current_time() -> datetime:
    # Get current date and time
    return datetime.now(timezone.utc).replace(microsecond=0)

# %%
current_time = get_current_time()

# %%
def round_time_to_minutes(
    dt: datetime, in_seconds: int, extra_seconds=0
) -> datetime:
    """round validation time to the closest minute and add extra minutes

    Args:
        dt (datetime): request_time
        in_seconds (int): 60
        extra_seconds (int, optional): self.timeout_extra_seconds: 120. Defaults to 0.

    Returns:
        datetime: rounded-up datetime
    """
    # Define the rounding interval
    rounding_interval = timedelta(seconds=in_seconds)

    # Calculate the number of seconds since the start of the day
    seconds = (
        dt - dt.replace(hour=0, minute=0, second=0, microsecond=0)
    ).total_seconds()

    # Calculate the next multiple of time_increment in seconds
    next_interval_seconds = (
        (seconds // rounding_interval.total_seconds()) + 1
    ) * rounding_interval.total_seconds()

    # Get the rounded-up datetime
    rounded_time = (
        dt.replace(hour=0, minute=0, second=0, microsecond=0)
        + timedelta(seconds=next_interval_seconds)
        + timedelta(seconds=extra_seconds)
    )

    return rounded_time

# %%
start_time = round_time_to_minutes(current_time, 60, 120)
simulation_input.start_time = start_time.isoformat()
print("start_time", simulation_input.start_time)
# Out:
# start_time 2025-09-15T09:06:00+00:00

# %%
import requests
TOKEN_MAP = {
    "BTC": "e62df6c8b4a85fe1a67db44dc12de5db330f7ac66b72dc658afedf0f4a415b43",
    "ETH": "ff61491a931112ddf1bd8147cd1b641375f79f5825126d665480874634fd0ace",
    "XAU": "765d2ba906dbc32ca17cc11f5310a89e9ee1f6420508c63861f2f8ba4ee34bb2",
    "SOL": "ef0d8b6fda2ceba41da15d4095d1da392a0d2f8ed0c6c7bc0f4cfac8c280b56d",
}

pyth_base_url = "https://hermes.pyth.network/v2/updates/price/latest"


def get_asset_price(asset="BTC"):
    pyth_params = {"ids[]": [TOKEN_MAP[asset]]}
    response = requests.get(pyth_base_url, params=pyth_params)
    if response.status_code != 200:
        print("Error in response of Pyth API")
        return

    data = response.json()
    parsed_data = data.get("parsed", [])

    asset = parsed_data[0]
    price = int(asset["price"]["price"])
    expo = int(asset["price"]["expo"])

    live_price = price * (10**expo)

    return live_price

# %%
from keras.models import Sequential
from keras.layers import Dense, GRU, Dropout
from keras.optimizers import Adam
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler
# Load model
    
model = Sequential()
model.add(GRU(units=288, return_sequences=True, input_shape=(289,1)))
model.add(Dropout(0.2))
# Second GRU layer with dropout
model.add(GRU(units=144, return_sequences=True))
model.add(Dropout(0.2))
# Third GRU layer with dropout
model.add(GRU(units=144, return_sequences=False))
model.add(Dropout(0.2))

# Output layer
model.add(Dense(units=289))

model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error', metrics=['mae'])

# %%
import numpy as np 
a=0
def simulate_single_price_path(
    current_price, time_increment, time_length, sigma
):
    """
    Simulate a single crypto asset price path.
    """
    one_hour = 3600
    dt = time_increment / one_hour
    num_steps = int(time_length / time_increment)
    std_dev = sigma * np.sqrt(dt)
    price_change_pcts = np.random.normal(0, std_dev, size=num_steps)
    cumulative_returns = np.cumprod(1 + price_change_pcts)
    cumulative_returns = np.insert(cumulative_returns, 0, 1.0)
    price_path = current_price * cumulative_returns
    
    
    
    data = pd.read_csv('./Data/btcusd_5-min_data.csv')
    x = pd.DataFrame(data['Close'])[:289]
    X_scaler = StandardScaler()
    x = X_scaler.fit_transform(x)
    x = np.array(x)
    x = np.array([np.reshape(x, [289])])
    price_path =  model.predict(x)
    price_path = X_scaler.inverse_transform(price_path)
    print(price_path.shape)
    return np.reshape(price_path, [289])

def simulate_crypto_price_paths(
    current_price, time_increment, time_length, num_simulations, sigma
):
    """
    Simulate multiple crypto asset price paths.
    """

    price_paths = []
    for _ in range(num_simulations):
        print(_)
        price_path = simulate_single_price_path(
            current_price, time_increment, time_length, sigma
        )
        price_paths.append(price_path)

    return np.array(price_paths)

def convert_prices_to_time_format(prices, start_time, time_increment):
    """
    Convert an array of float numbers (prices) into an array of dictionaries with 'time' and 'price'.

    :param prices: List of float numbers representing prices.
    :param start_time: ISO 8601 string representing the start time.
    :param time_increment: Time increment in seconds between consecutive prices.
    :return: List of dictionaries with 'time' and 'price' keys.
    """
    start_time = datetime.fromisoformat(
        start_time
    )  # Convert start_time to a datetime object
    result = []

    for price_item in prices:
        single_prediction = []
        for i, price in enumerate(price_item):
            time_point = start_time + timedelta(seconds=i * time_increment)
            single_prediction.append(
                {"time": time_point.isoformat(), "price": price}
            )
        result.append(single_prediction)

    return result

# %%
def generate_simulations(
    asset="BTC",
    start_time: str = "",
    time_increment=300,
    time_length=86400,
    num_simulations=1,
    sigma=0.01,
):
    """
    Generate simulated price paths.

    Parameters:
        asset (str): The asset to simulate. Default is 'BTC'.
        start_time (str): The start time of the simulation. Defaults to current time.
        time_increment (int): Time increment in seconds.
        time_length (int): Total time length in seconds.
        num_simulations (int): Number of simulation runs.
        sigma (float): Standard deviation of the simulated price path.

    Returns:
        numpy.ndarray: Simulated price paths.
    """
    if start_time == "":
        raise ValueError("Start time must be provided.")

    current_price = get_asset_price(asset)
    print(current_price)
    if current_price is None:
        raise ValueError(f"Failed to fetch current price for asset: {asset}")

    if asset == "BTC":
        sigma *= 3
    elif asset == "ETH":
        sigma *= 1.25
    elif asset == "XAU":
        sigma *= 0.5
    elif asset == "SOL":
        sigma *= 0.75

    simulations = simulate_crypto_price_paths(
        current_price=current_price,
        time_increment=time_increment,
        time_length=time_length,
        num_simulations=num_simulations,
        sigma=sigma,
    )

    predictions = convert_prices_to_time_format(
        simulations.tolist(), start_time, time_increment
    )
    return predictions

# %%
import typing
def datetime_valid(dt_str) -> bool:
    try:
        datetime.fromisoformat(dt_str)
    except ValueError:
        return False
    return True
def validate_datetime(
    dt_str,
) -> typing.Tuple[datetime, typing.Optional[str]]:
    if not isinstance(dt_str, str):
        return (
            datetime.now(),
            f"Time format is incorrect: expected str, got {type(dt_str)}",
        )
    if not datetime_valid(dt_str):
        return (
            datetime.now(),
            f"Time format is incorrect: expected isoformat, got {dt_str}",
        )

    return datetime.fromisoformat(dt_str), None

def validate_responses(
    response,
    simulation_input: SimulationInput,
    request_time: datetime,
    process_time_str: typing.Optional[str],
) -> str:
    """
    Validate responses from miners.

    Return a string with the error message
    if the response is not following the expected format or the response is empty,
    otherwise, return "CORRECT".
    """
    # check the process time
    if process_time_str is None:
        return "time out or internal server error (process time is None)"

    received_at = request_time + timedelta(seconds=float(process_time_str))
    start_time = datetime.fromisoformat(simulation_input.start_time)
    if received_at > start_time:
        return f"Response received after the simulation start time: expected {start_time}, got {received_at}"

    # check if the response is empty
    if response is None or len(response) == 0:
        return "Response is empty"

    # check the number of paths
    if len(response) != simulation_input.num_simulations:
        return f"Number of paths is incorrect: expected {simulation_input.num_simulations}, got {len(response)}"

    for path in response:
        # check the number of time points
        expected_time_points = (
            simulation_input.time_length // simulation_input.time_increment + 1
        )
        if len(path) != expected_time_points:
            return f"Number of time points is incorrect: expected {expected_time_points}, got {len(path)}"

        # check the start time
        first_time = path[0].get("time", "")
        if first_time != simulation_input.start_time:
            return f"Start time is incorrect: expected {simulation_input.start_time}, got {first_time}"

        for i in range(1, len(path)):
            # check the time formats
            i_minus_one_str_time = path[i - 1].get("time", "")
            i_minus_one_datetime, error_message = validate_datetime(
                i_minus_one_str_time
            )
            if error_message:
                return error_message

            i_str_time = path[i].get("time", "")
            i_datetime, error_message = validate_datetime(i_str_time)
            if error_message:
                return error_message

            # check the time increment
            expected_delta = timedelta(seconds=simulation_input.time_increment)
            actual_delta = i_datetime - i_minus_one_datetime
            if actual_delta != expected_delta:
                return f"Time increment is incorrect: expected {expected_delta}, got {actual_delta}"

            # check the price format
            price = path[i].get("price")
            if not isinstance(price, (int, float)):
                return f"Price format is incorrect: expected int or float, got {type(price)}"

    return "CORRECT"

# %%
prediction = generate_simulations(
        simulation_input.asset,
        start_time=simulation_input.start_time,
        time_increment=simulation_input.time_increment,
        time_length=simulation_input.time_length,
        num_simulations=simulation_input.num_simulations,
    )
format_validation = validate_responses(
        prediction,
        simulation_input,
        datetime.fromisoformat(simulation_input.start_time),
        "0",
    )
format_validation
# Out:
# 114881.90000000001
# 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 596ms/step
# (1, 289)
# 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 479ms/step
# (1, 289)
# 2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# (1, 289)
# 'CORRECT'

# %%
import requests
import pandas as pd
import time

def get_historical_btc_data(days=365):
    """
    Fetches historical BTC price data for a specified number of days.
    
    Parameters:
    days (int): Number of days of historical data to fetch (max=365 for free tier)
    
    Returns:
    pandas.DataFrame: DataFrame with timestamp, price, and other metrics.
    """
    url = f"https://api.coingecko.com/api/v3/coins/bitcoin/market_chart"
    params = {
        'vs_currency': 'usd',
        'days': days,
        'interval': 'daily'  # 'daily' or 'hourly' for more granular data
    }
    
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36'
    }
    
    try:
        response = requests.get(url, params=params, headers=headers, timeout=30)
        response.raise_for_status()
        data = response.json()
        
        # Extract prices and convert to DataFrame
        prices = data['prices']
        df = pd.DataFrame(prices, columns=['timestamp', 'price'])
        
        # Convert timestamp to readable date
        df['date'] = pd.to_datetime(df['timestamp'], unit='ms')
        
        # Add other metrics if available
        if 'market_caps' in data:
            market_caps = data['market_caps']
            df['market_cap'] = [cap[1] for cap in market_caps]
        
        if 'total_volumes' in data:
            volumes = data['total_volumes']
            df['volume'] = [vol[1] for vol in volumes]
        
        # Reorder columns
        df = df[['timestamp', 'date', 'price', 'market_cap', 'volume']]
        
        return df
        
    except requests.exceptions.RequestException as e:
        print(f"Request failed: {e}")
        return None

# Get 30 days of BTC data
btc_data = get_historical_btc_data(days=1000)

if btc_data is not None:
    # Save to CSV
    btc_data.to_csv('btc_historical_data.csv', index=False)
    print("BTC historical data saved to 'btc_historical_data.csv'")
    print(f"Data shape: {btc_data.shape}")
    print(btc_data.head())
else:
    print("Failed to fetch BTC data")
# Out:
# Request failed: 401 Client Error: Unauthorized for url: https://api.coingecko.com/api/v3/coins/bitcoin/market_chart?vs_currency=usd&days=1000&interval=daily
# Failed to fetch BTC data

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# Scrape subnet data from TAOStats
url = "https://taostats.io/subnets/"
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

try:
    response = requests.get(url, headers=headers, timeout=10)
    response.raise_for_status()  # Raise an exception for HTTP errors
    
    # Parse the HTML content
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Find all tables on the page
    tables = soup.find_all('table')
    
    if not tables:
        print("No tables found on the page")
    else:
        # Try to extract data from each table until we find the right one
        for i, table in enumerate(tables):
            try:
                # Convert table to DataFrame
                df = pd.read_html(str(table))[0]
                
                # Check if this looks like the subnet table (has expected columns)
                if 'UID' in df.columns and 'Name' in df.columns:
                    print(f"Found subnet table at position {i}")
                    df.to_csv('taostats_subnets.csv', index=False)
                    print("Data successfully saved to taostats_subnets.csv")
                    break
            except Exception as e:
                print(f"Error processing table {i}: {e}")
                continue
        else:
            print("Could not find the subnet table with expected columns")
            
except requests.exceptions.RequestException as e:
    print(f"Request failed: {e}")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Request failed: 500 Server Error: Internal Server Error for url: https://taostats.io/subnets

# %%
import bittensor as bt
import pandas as pd

# Connect to Bittensor network
subtensor = bt.subtensor(network='finney')  # Use 'test' for testnet

# Get all subnets information
subnets = subtensor.get_all_subnets_info()
subnets
# Out:
# [SubnetInfo(netuid=0, rho=10, kappa=32767, difficulty=4611686018427387903, immunity_period=4096, max_allowed_validators=64, min_allowed_weights=0, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=64, max_n=64, blocks_since_epoch=440, tempo=100, modality=0, connection_requirements={}, emission_value=0, burn=τ0.000500000, owner_ss58='5C4hrfjw9DjXZTzV3MwzrrAr9P1MJhSrvWGWqi1eSuyUpnhM'),
#  SubnetInfo(netuid=1, rho=10, kappa=32767, difficulty=10000000, immunity_period=7200, max_allowed_validators=128, min_allowed_weights=8, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=1024, max_n=1024, blocks_since_epoch=23, tempo=99, modality=0, connection_requirements={}, emission_value=0, burn=τ0.066468716, owner_ss58='5HCFWvRqzSHWRPecN7q8J6c7aKQnrCZTMHstPv39xL1wgDHh'),
#  SubnetInfo(netuid=2, rho=10, kappa=32767, difficulty=1268010552201, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=261, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.043267360, owner_ss58='5EcYQ3W77ndrmMWdvVQusoFqY8doxfP3U2zrh7xZQiaz7avY'),
#  SubnetInfo(netuid=3, rho=10, kappa=32767, difficulty=10000000, immunity_period=10000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=262, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.000500000, owner_ss58='5G26HqQg8M6hfw9q84gM3udYHHymThmswRKgSGtwdcduBSos'),
#  SubnetInfo(netuid=4, rho=10, kappa=32767, difficulty=10000000, immunity_period=7520, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=263, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.000500000, owner_ss58='5CXGPMnq9RCCLUEvp9G2iUuabw69TSFM155UVS1S4Zmusaxv'),
#  SubnetInfo(netuid=5, rho=10, kappa=32767, difficulty=10000000, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=264, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.001506825, owner_ss58='5GurNtB3yQFCh6CSmfH7LrYJDsvzup4diHZiaYtKe274nrMX'),
#  SubnetInfo(netuid=6, rho=10, kappa=32767, difficulty=10000000, immunity_period=21600, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=265, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.061308278, owner_ss58='5CfSg4e23Z3aTXvc2XZie8ZE1xkqRPoyVRFdWUuyyjGxJrMA'),
#  SubnetInfo(netuid=7, rho=10, kappa=32767, difficulty=10000000, immunity_period=10800, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=266, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.032129359, owner_ss58='5DFjDQHdKZ32mQRDFpfkzrDdQf65NamVibKvV8PYJaeJ8eH6'),
#  SubnetInfo(netuid=8, rho=10, kappa=32767, difficulty=63628400947, immunity_period=8191, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=267, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.092066428, owner_ss58='5F6tnxzAAxbhaWRmeUmB63JEM3VXBNSmqb3AwYJVDStQjw8y'),
#  SubnetInfo(netuid=9, rho=10, kappa=23000, difficulty=10000000, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=268, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.040227973, owner_ss58='5FsbubeciqtB5Nik3umL2iD4fG8FcC9GbT9nHJfXMj4mJJZ9'),
#  SubnetInfo(netuid=10, rho=10, kappa=32767, difficulty=10000000, immunity_period=12600, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=269, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.015137123, owner_ss58='5EvNESR7DfSMmdwJ3crtBW1ENAhq3f99X4FCbTi1hDUNCWAW'),
#  SubnetInfo(netuid=11, rho=10, kappa=32767, difficulty=10000000, immunity_period=10800, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=270, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.000569798, owner_ss58='5EtM9iXMAYRsmt6aoQAoWNDX6yaBnjhmnEQhWKv8HpwkVtML'),
#  SubnetInfo(netuid=12, rho=10, kappa=32767, difficulty=10000000, immunity_period=1466, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=271, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.000500000, owner_ss58='5ELzhHvgUqmnAYs74vFWjMMehXNeHkRtkreAa3g8QQS96PCp'),
#  SubnetInfo(netuid=13, rho=10, kappa=32767, difficulty=10000000, immunity_period=12000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=272, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.185142357, owner_ss58='5HBswBt1A9Ahx6U76abXXGd7VmabmCNBGhSK2vrP71GSxtgZ'),
#  SubnetInfo(netuid=14, rho=10, kappa=32767, difficulty=10000000, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=273, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.000500000, owner_ss58='5CKhH8nKAhXLmqxwaXzFtVFgxqwwnyckXG8qLpmGtzVJH9Ri'),
#  SubnetInfo(netuid=15, rho=10, kappa=32767, difficulty=10000000, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=274, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.124320021, owner_ss58='5FjUGgsteDT745K8AMZDcB59sVkQcMAGGcgATm39Xo26tyq2'),
#  SubnetInfo(netuid=16, rho=10, kappa=32767, difficulty=10000000, immunity_period=3600, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=275, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.000500000, owner_ss58='5HGvv62eWd6BUXM8HaJPMguzNragaJMfLTENYBCcDrgsSAFb'),
#  SubnetInfo(netuid=17, rho=10, kappa=32767, difficulty=10000000, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=276, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.424728469, owner_ss58='5E7a4a7QETrNjoZ2SbVSJMaavrQeyTEaHgjBPDUDxBKjUaMZ'),
#  SubnetInfo(netuid=18, rho=10, kappa=32767, difficulty=10000000, immunity_period=8100, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=277, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.124013869, owner_ss58='5DHwWLjtpwnZQUQKKXE2N5Gdy2N8PpqhgjLUuzgSB7yuGZkF'),
#  SubnetInfo(netuid=19, rho=10, kappa=32767, difficulty=10000000, immunity_period=7000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=278, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.001906863, owner_ss58='5CFJNoUYbdw9NvU2MuvQuxG88BWBKYbEQPxg1sVieck16TRq'),
#  SubnetInfo(netuid=20, rho=10, kappa=32767, difficulty=10000000, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=279, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.000500000, owner_ss58='5FuzgvtfbZWdKSRxyYVPAPYNaNnf9cMnpT7phL3s2T3Kkrzo'),
#  SubnetInfo(netuid=21, rho=10, kappa=32767, difficulty=10000000, immunity_period=10800, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=280, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.007527859, owner_ss58='5Gjn5fERZjM75JPc999TEqmAuR6VNC6MhUWdSABhp3okY6cx'),
#  SubnetInfo(netuid=22, rho=10, kappa=32767, difficulty=10000000, immunity_period=7200, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=281, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.011041500, owner_ss58='5DFuaMasyQtPhXcsuoYEyJmCVSRtzKxsTKFTA4SrpcGXBxJn'),
#  SubnetInfo(netuid=23, rho=10, kappa=32767, difficulty=10000000, immunity_period=15000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=282, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.000500000, owner_ss58='5GvTa4JUKbUHqeJH8YLUDaV7jHChrfUy4n5zWrcCiU7bySoc'),
#  SubnetInfo(netuid=24, rho=10, kappa=32767, difficulty=10000000, immunity_period=10800, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=283, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.028832516, owner_ss58='5HEQXo8MsUKAUDZuzLtCPaBRTVYUvCkXcV1bKywQ4oQDemZQ'),
#  SubnetInfo(netuid=25, rho=10, kappa=32767, difficulty=10000000, immunity_period=21600, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=284, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.000500000, owner_ss58='5F6aRdsBHajN2NhZHBTB6ibBFu7YuZZEWruWzB8x6B6GiZ4D'),
#  SubnetInfo(netuid=26, rho=10, kappa=32767, difficulty=10000000, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=285, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.004000000, owner_ss58='5GsfAD4a3KXYKx2TF9UcajcW6C85Bw5vZsCTmrFep7RgMjcm'),
#  SubnetInfo(netuid=27, rho=10, kappa=32767, difficulty=10000000, immunity_period=7200, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=286, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.000500000, owner_ss58='5Cyfk5Jjee6uCafjZyUUjtKd7Q4qh1yJ48Ts7bkT9xXaDqe1'),
#  SubnetInfo(netuid=28, rho=10, kappa=32767, difficulty=10000000, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=287, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.000677702, owner_ss58='5GKYVYof1CbEuNcnBSa2wXx3rs5StYYVBPdg8C5CQ8MifCBc'),
#  SubnetInfo(netuid=29, rho=10, kappa=32767, difficulty=10000000, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=288, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.000500000, owner_ss58='5HHHHHzgLnYRvnKkHd45cRUDMHXTSwx7MjUzxBrKbY4JfZWn'),
#  SubnetInfo(netuid=30, rho=10, kappa=42598, difficulty=10000000, immunity_period=21600, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=289, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.017186752, owner_ss58='5DcErZoVeG7ZShXwKFgJURuGXmdAVwmYzyvLAgpPjrPznDMB'),
#  SubnetInfo(netuid=31, rho=10, kappa=32767, difficulty=10000000, immunity_period=7200, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=290, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.010984741, owner_ss58='5GeRN2PttXsNJ75d7Q4e5G5V35EUqBBuLeaACgEGyPUZdikr'),
#  SubnetInfo(netuid=32, rho=10, kappa=32767, difficulty=10000000, immunity_period=7200, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=291, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.000507160, owner_ss58='5DWgkCSvq4brWSNLDU9FBgTk1ZpAQ2y6t3ky97CvEVuS9Qad'),
#  SubnetInfo(netuid=33, rho=10, kappa=32767, difficulty=1196911173, immunity_period=7200, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=292, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ2.698816132, owner_ss58='5HinUfk5SqBUAbkMtgdNoum3VJvwrLgdvwW5sbXA1UPYZ8uB'),
#  SubnetInfo(netuid=34, rho=10, kappa=32767, difficulty=951123983607, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=293, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.188470315, owner_ss58='5DthmKBR83sUdudSfgFnsxBkTYtYTFLJUgovNfb1TSKVLiTH'),
#  SubnetInfo(netuid=35, rho=10, kappa=32767, difficulty=10000000, immunity_period=7200, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=294, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.000551656, owner_ss58='5GmWJkzKAErRpS3AHyj7uJLzETG9Ed7VVCMr7rmha9YkMR6X'),
#  SubnetInfo(netuid=36, rho=10, kappa=32767, difficulty=10000000, immunity_period=7200, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=295, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.176707743, owner_ss58='5DPtMdkMau8G8fGbPxdYSKCBo94oC7mDyHKMvVdNdsLVT3EF'),
#  SubnetInfo(netuid=37, rho=10, kappa=32767, difficulty=10000000, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=296, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.000500000, owner_ss58='5DXqqdrvu5FK3dASRVTCdGPZKx4Q9nkAZZSmibKG6PEEeW4j'),
#  SubnetInfo(netuid=38, rho=10, kappa=32767, difficulty=10000000, immunity_period=7920, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=297, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.031655938, owner_ss58='5EFJ7mEVyjxT3iXqxuHyMMuGgJKFt85tb5s4vEvnCTpSoP3w'),
#  SubnetInfo(netuid=39, rho=10, kappa=13107, difficulty=10000000, immunity_period=15000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=298, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.000500000, owner_ss58='5Fq9HB8RiFug83r44Focqt9Wk2UZJC76wXKqSuTVV9kXYePh'),
#  SubnetInfo(netuid=40, rho=10, kappa=32767, difficulty=10000000, immunity_period=14400, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=299, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.000500000, owner_ss58='5F9Qvcz22Fwq4cm58o2bShiL6n8BnJmhqXB1cispBpqRfN6w'),
#  SubnetInfo(netuid=41, rho=10, kappa=32767, difficulty=10000000, immunity_period=14400, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=300, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.576000000, owner_ss58='5FCSevLkofmKZRixMawp6jyyjBty1AeSCLa7N5Fv892DYkXX'),
#  SubnetInfo(netuid=42, rho=10, kappa=32767, difficulty=10000000, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=301, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.102315019, owner_ss58='5Gbdb5s2WrRaFXTgMUiVNBKACe3cgSLwZNyK2Vwvjfvf6jUJ'),
#  SubnetInfo(netuid=43, rho=10, kappa=32767, difficulty=754747111870694951, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=302, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.013439496, owner_ss58='5HjMs5JDrLH3Hknmfm1gDq7nFYAv6M7t9v3EWMctSRXJS9HC'),
#  SubnetInfo(netuid=44, rho=10, kappa=32767, difficulty=10000000, immunity_period=10800, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=303, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.785466338, owner_ss58='5CaCekuxb9pKQyLoxh3jbkEXig8fxjkeS4AQ6UmZa12xfQ9H'),
#  SubnetInfo(netuid=45, rho=10, kappa=32767, difficulty=10000000, immunity_period=7200, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=304, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.000562881, owner_ss58='5FbcZiAHA75i2bPVrF7wa9mFaxV1eM27HR63kJtbpb8spvmf'),
#  SubnetInfo(netuid=46, rho=10, kappa=32767, difficulty=10000000, immunity_period=7200, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=305, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.000500000, owner_ss58='5Ft9E2ovN52AVMczVA3713uXmmBPczvUboB4YQpupu3aEYg7'),
#  SubnetInfo(netuid=47, rho=10, kappa=32767, difficulty=10000000, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=306, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.173642925, owner_ss58='5CLyhrqcMHvrpzHDHpmn71qy1AEdrRzfyW9n3Kne8dnQB3du'),
#  SubnetInfo(netuid=48, rho=10, kappa=32767, difficulty=10000000, immunity_period=2000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=307, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.001000000, owner_ss58='5GNH5YMkcX8jEF1PukvxKafifcqz13jp18BT73jRL3AZc4Rc'),
#  SubnetInfo(netuid=49, rho=10, kappa=32767, difficulty=10000000, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=308, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.000500000, owner_ss58='5G4LA1YaL6sMF2xLuZvaYEXiTWkSJbDwHxF8bwuoTUq7Fzs4'),
#  SubnetInfo(netuid=50, rho=10, kappa=32767, difficulty=57033831744, immunity_period=50400, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=309, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.447349049, owner_ss58='5DxyiWpGqN5xXiczXcEGph51BcgTqcYKD5GKZqoACuc2sJkD'),
#  SubnetInfo(netuid=51, rho=10, kappa=16384, difficulty=18446744073709551615, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=310, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.500000000, owner_ss58='5FqACMtcegZxxopgu1g7TgyrnyD8skurr9QDPLPhxNQzsThe'),
#  SubnetInfo(netuid=52, rho=10, kappa=32767, difficulty=10000000, immunity_period=10800, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=311, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.001673978, owner_ss58='5HRmFCn6G7Y5yimb5VwLpxfN9mwHVMs177kzxnRpoSWbzgHs'),
#  SubnetInfo(netuid=53, rho=10, kappa=32767, difficulty=10000000, immunity_period=1, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=312, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.000500000, owner_ss58='5F2HTUqtk9VWQwXkkUX9oFSXUkAib74qw7s3W7KyZP88AmYe'),
#  SubnetInfo(netuid=54, rho=10, kappa=32767, difficulty=10000000, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=313, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.337722747, owner_ss58='5FUfruyVDoDsCty1Sh7tCmHVdpoC3XV1nUZYjhcpfe31Defk'),
#  SubnetInfo(netuid=55, rho=10, kappa=32767, difficulty=10000000, immunity_period=7200, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=314, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.156613962, owner_ss58='5HmHiVeddZPNqjUJLccRiq5AVMTVaNYif5EQNrE5fumcf46r'),
#  SubnetInfo(netuid=56, rho=10, kappa=32767, difficulty=10000000, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=315, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.000500000, owner_ss58='5G77DNXrfAxbvi53p3mh88kRMySBcJsv9j9cH4KU6ALWXgQF'),
#  SubnetInfo(netuid=57, rho=10, kappa=32767, difficulty=10000000, immunity_period=28800, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=316, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.001000000, owner_ss58='5GmhjCqDTsRcKqPFw4FDig8tVBfFGNrwP8ywe5En5hnELwDQ'),
#  SubnetInfo(netuid=58, rho=10, kappa=32767, difficulty=10000000, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=317, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.000500000, owner_ss58='5DyEYZ2pB3bP6BN8Xpo5ova3TEPiT82j5oHXqgQ8csKE9stH'),
#  SubnetInfo(netuid=59, rho=10, kappa=32767, difficulty=10000000, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=318, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.000500000, owner_ss58='5D7ZJy3DgrTuSvkju4SCwLfKdbXaXpDfGzfBmLSuLZPqBVxT'),
#  SubnetInfo(netuid=60, rho=10, kappa=32767, difficulty=10000000, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=319, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.045200775, owner_ss58='5CXLwkK1Scd1uiMUrXYjJUTTPxqqyH2FTJQNLp9uXQhA9rhR'),
#  SubnetInfo(netuid=61, rho=10, kappa=32767, difficulty=10000000, immunity_period=14400, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=320, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.000500000, owner_ss58='5ECEsYL82fbXx9KfTZy7G2KXSurnScciJyAVMHZjekc8jUbn'),
#  SubnetInfo(netuid=62, rho=10, kappa=32767, difficulty=10000000, immunity_period=7400, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=321, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.411806703, owner_ss58='5F1uxPLnv9uZqUCVHpwirnUNoybiEKuAAoJe5pv4rEHbJy1N'),
#  SubnetInfo(netuid=63, rho=10, kappa=32767, difficulty=10000000, immunity_period=10000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=322, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.226375973, owner_ss58='5CqTmNfgDchxULD1bfoz8jvj9rDYSoq76kiq98oBUUEDpWqX'),
#  SubnetInfo(netuid=64, rho=10, kappa=32767, difficulty=10000000, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=323, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.000500000, owner_ss58='5DyV8a62E2t2C4FoSqjihdV5USVXPEZYvZtUjXxZq1Mnvwwg'),
#  SubnetInfo(netuid=65, rho=10, kappa=32767, difficulty=18446744073709551615, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=324, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.006304141, owner_ss58='5GxEEHxLWpvcAGghL8LG7xNjrxZk4SEPW1VT43hGPZ2TP9mZ'),
#  SubnetInfo(netuid=66, rho=10, kappa=32767, difficulty=18446744073709551615, immunity_period=6080, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=325, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.000500000, owner_ss58='5E9oJhMQd7qagGD4HNMbRQzaQVDvLjVr76U5wvg4Poxv5pvj'),
#  SubnetInfo(netuid=67, rho=10, kappa=32767, difficulty=18446744073709551615, immunity_period=31200, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=326, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.000545985, owner_ss58='5D2knCMRNdMaag6DLcP3e1bBA27FiSoYh8CpndsuEWohhRos'),
#  SubnetInfo(netuid=68, rho=10, kappa=32767, difficulty=18446744073709551615, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=327, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.004000000, owner_ss58='5EcdJLAeYoxM3Tsf5VZ3NQPenPku218gqnjSoo3iJNy4V12V'),
#  SubnetInfo(netuid=69, rho=10, kappa=32767, difficulty=18446744073709551615, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=328, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.000500000, owner_ss58='5EsorPyFCP7TaNz3QrNvDvr8ZDVtG9hfzNEfGeAVG9wbFi2B'),
#  SubnetInfo(netuid=70, rho=10, kappa=32767, difficulty=18446744073709551615, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=329, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.069893934, owner_ss58='5GayCfNEMcf3jLsVbXK9wMNsWpXg6axNSooPAeKuJfjJfkSz'),
#  SubnetInfo(netuid=71, rho=10, kappa=32767, difficulty=18446744073709551615, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=330, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.000633393, owner_ss58='5FsPeCzuwm7e3QLqGjXZMzM3hJMVcS7Ga1L7dYTuA3yYfhhT'),
#  SubnetInfo(netuid=72, rho=10, kappa=32767, difficulty=18446744073709551615, immunity_period=21600, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=331, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.379276178, owner_ss58='5HTYVBxrF2WbVN8RBtFxAkBGuHJxjgLd9Sze5gxH4KC6GLCv'),
#  SubnetInfo(netuid=73, rho=10, kappa=32767, difficulty=18446744073709551615, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=332, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.000500000, owner_ss58='5EWdfGjSKJ9jP6GH427s6Nj4jjhUTxaenExHH433eFi8wJ3J'),
#  SubnetInfo(netuid=74, rho=10, kappa=32767, difficulty=18446744073709551615, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=333, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.000500000, owner_ss58='5HdKJJHNG2Zh2rkSrHjPoRa8xQ9Mq8NgQwfREDCpTawLa1aQ'),
#  SubnetInfo(netuid=75, rho=10, kappa=32767, difficulty=18446744073709551615, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=334, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.119169699, owner_ss58='5DAQpczEK4vzBn1waHkC4BZGqGPZ1dwPxKVsj36JDofHAw3a'),
#  SubnetInfo(netuid=76, rho=10, kappa=32767, difficulty=18446744073709551615, immunity_period=14400, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=335, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.001687510, owner_ss58='5FeGCWfKjMLtRFapACp4YU4JgU2sPDB6MGkkx6PvXoL6MVGH'),
#  SubnetInfo(netuid=77, rho=10, kappa=32767, difficulty=18446744073709551615, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=336, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.000500000, owner_ss58='5GxxsUeYRyJSJKCuPeG1jZZiCummHJttmTNsfgDRSfxVnhGi'),
#  SubnetInfo(netuid=78, rho=10, kappa=32767, difficulty=18446744073709551615, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=337, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.000549010, owner_ss58='5FxyfeqQi5DL88jwyz3pPZFww3WUbKHJT6Vdhe3kx6ML8V6R'),
#  SubnetInfo(netuid=79, rho=10, kappa=32767, difficulty=18446744073709551615, immunity_period=7200, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=338, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.052776472, owner_ss58='5Fxp7QBG81X7PLdMkAe1RLCvqqfQSw9rJC5ppEQs9FP8qez9'),
#  SubnetInfo(netuid=80, rho=10, kappa=32767, difficulty=18446744073709551615, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=339, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.000500000, owner_ss58='5FCx75JcnrQeAma2eHHGoweCgNSqfs8sRCNwTDSriuGERXoa'),
#  SubnetInfo(netuid=81, rho=10, kappa=32767, difficulty=18446744073709551615, immunity_period=10799, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=340, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.035702852, owner_ss58='5Ckv5w2PLg9yeWA62cS6XYNUtorKQAeJLmaUgZ1sKMttEadb'),
#  SubnetInfo(netuid=82, rho=10, kappa=32767, difficulty=18446744073709551615, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=341, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.000000001, owner_ss58='5CQGGDxtZrtpMJGpjXqEP3pkwmqfwwYs1knmYnQGjGs8MMgS'),
#  SubnetInfo(netuid=83, rho=10, kappa=16384, difficulty=18446744073709551615, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=342, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.458846639, owner_ss58='5DqEjRLyNN8k3WbEXhA36tyGG4YpWyPEcVSTa47XxspNHhc3'),
#  SubnetInfo(netuid=84, rho=10, kappa=32767, difficulty=18446744073709551615, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=343, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.000949246, owner_ss58='5FBwsAvvKjhe7bGSdtVSAaxm7huJAcWFZRb9WRpJJmrVUvoB'),
#  SubnetInfo(netuid=85, rho=10, kappa=32767, difficulty=18446744073709551615, immunity_period=7000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=344, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.088502068, owner_ss58='5GQxLKxjZWNZDsghmYcw7P6ahC7XJCjx1WD94WGh92quSycx'),
#  SubnetInfo(netuid=86, rho=10, kappa=32767, difficulty=18446744073709551615, immunity_period=100, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=345, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.000500000, owner_ss58='5FeUPcVYLfsWWBUhkp3qZyV1t4pPtpJgkAaX46oVt6BAkSU8'),
#  SubnetInfo(netuid=87, rho=10, kappa=32767, difficulty=18446744073709551615, immunity_period=21600, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=346, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.020226263, owner_ss58='5F7htCtokENtASnNNSQmiDL9TF68dGJPqXZn95pditUH12tw'),
#  SubnetInfo(netuid=88, rho=10, kappa=32767, difficulty=18446744073709551615, immunity_period=21600, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=347, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.104459279, owner_ss58='5G9agSicRvykC6i4Ysqapyk9ed4FvqqkTAKaQQWGjno8erAA'),
#  SubnetInfo(netuid=89, rho=10, kappa=32767, difficulty=18446744073709551615, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=348, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.000500000, owner_ss58='5Dc5NmEUptDeMLrxDSvg8kfCToxJkiF47apAYSVTycAVvDN4'),
#  SubnetInfo(netuid=90, rho=10, kappa=32767, difficulty=18446744073709551615, immunity_period=10000, max_allowed_validators=64, min_allowed_weights=8, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=349, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.076582301, owner_ss58='5GbuKCxZ8eukNyzikWDUAA7YBRjkDGDBR89cWKMKLr8C29U8'),
#  SubnetInfo(netuid=91, rho=10, kappa=32767, difficulty=18446744073709551615, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=350, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.000500000, owner_ss58='5E7dez1zSF5L5NPSTYBrRRP8K5r7kKGNuwnrtzspHNP9n3EA'),
#  SubnetInfo(netuid=92, rho=10, kappa=32767, difficulty=18446744073709551615, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=351, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.000530452, owner_ss58='5FxLq2TNzG5HbPga69m52SQ5esT8wv3mZUBqC8ibtg6JCpPf'),
#  SubnetInfo(netuid=93, rho=10, kappa=32767, difficulty=18446744073709551615, immunity_period=50400, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=352, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.000500000, owner_ss58='5FLfN276taTF6Ud62soChQhPNbtF2EPK4dr3pJB9oTsTpUvr'),
#  SubnetInfo(netuid=94, rho=10, kappa=32767, difficulty=18446744073709551615, immunity_period=12000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=353, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.047280885, owner_ss58='5EPDZN72foPHFXYYGdKaiUTPWiQVZ9ySrZH6UeWduDxKJnaP'),
#  SubnetInfo(netuid=95, rho=10, kappa=32767, difficulty=18446744073709551615, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=354, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.000640310, owner_ss58='5D5UhUuc6cC47CXUBHyBkpDBrdeyeL6bpWGAreZgNm5WTyrg'),
#  SubnetInfo(netuid=96, rho=10, kappa=32767, difficulty=18446744073709551615, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=355, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.175701654, owner_ss58='5D7bAeb7ybS72vpxsH9Wrutein45ZDp7a5Vi4uogsZ5BZnzJ'),
#  SubnetInfo(netuid=97, rho=10, kappa=32767, difficulty=18446744073709551615, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=356, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.035210547, owner_ss58='5EXSiTySWQiuzowhogXzfCr4Xn45CW3oMELWGTxFEfQCTy86'),
#  SubnetInfo(netuid=98, rho=10, kappa=32767, difficulty=18446744073709551615, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=357, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.000570817, owner_ss58='5Dd9Q6yueRkH1fLTHa2xdEEPoMQiqenWKRMUtZKPTuvjRL3w'),
#  SubnetInfo(netuid=99, rho=10, kappa=32767, difficulty=18446744073709551615, immunity_period=20000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=358, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.000533934, owner_ss58='5EFSqmNR49Yt6NLHc45ixSBUUtakjtT3ew3SwV3KiDWAvgzn'),
#  SubnetInfo(netuid=100, rho=10, kappa=32767, difficulty=18446744073709551615, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=359, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.000649936, owner_ss58='5Ccm1EBF7XeC3Fz3ncAZDPWheaHSk85aMZxmxoShpAk8PFk3'),
#  SubnetInfo(netuid=101, rho=10, kappa=32767, difficulty=18446744073709551615, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=360, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.000500000, owner_ss58='5H8dNvi1jZRe1dcYN2FdknWKxfGx6u1o9pYm5zRMCZyy2Ex3'),
#  SubnetInfo(netuid=102, rho=10, kappa=32767, difficulty=18446744073709551615, immunity_period=14400, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=0, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.088302928, owner_ss58='5HnEhgyg9sKo4J2Q8dZMUm8JtcnVvf2WjcnXnqzU8YbYLJUm'),
#  SubnetInfo(netuid=103, rho=10, kappa=32767, difficulty=18446744073709551615, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=1, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.118572867, owner_ss58='5F4unP1RmimJ8wVoyBi3ZUQ2LAEuBYKTw4ov3mHWVkeBhEjD'),
#  SubnetInfo(netuid=104, rho=10, kappa=13108, difficulty=18446744073709551615, immunity_period=0, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=2, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.001000000, owner_ss58='5HBb3F1bmDzdwQ5WTweXUvnKETTzu6aWNAH811vrLkvSdQAn'),
#  SubnetInfo(netuid=105, rho=10, kappa=32767, difficulty=18446744073709551615, immunity_period=30000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=3, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.001642689, owner_ss58='5GbcXUiCWBDdgFTBKPQUh5aVjqZr2mgfMPPUmYxkSq6nGaFq'),
#  SubnetInfo(netuid=106, rho=10, kappa=32767, difficulty=18446744073709551615, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=4, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.000515001, owner_ss58='5E5Ctr2D9SjvLwNn45UNhBpjuQ7QWuinMqpAXY1ueRfJr5PT'),
#  SubnetInfo(netuid=107, rho=10, kappa=32767, difficulty=18446744073709551615, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=5, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.081132452, owner_ss58='5EjS4kzFCMZHrXSY1U5zhx7Math8S4JiUXXVPCKsD8XE19Tq'),
#  SubnetInfo(netuid=108, rho=10, kappa=13107, difficulty=18446744073709551615, immunity_period=100, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=6, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.000500000, owner_ss58='5HVdRa76MD9dv6WgGVfRgzte7eKT1wxXMyp7iHA6L45i9GfU'),
#  SubnetInfo(netuid=109, rho=10, kappa=32767, difficulty=18446744073709551615, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=7, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.000609197, owner_ss58='5H6tB2G72y7K1LrM9XudEKJu8Pqsf5ZDtbn5N1SHqtFErPka'),
#  SubnetInfo(netuid=110, rho=10, kappa=32767, difficulty=18446744073709551615, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=8, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.000766166, owner_ss58='5Cns2aadeaNT6HYSGBZqQAhQyYSRGDZFmJKCJQKx1Bh1vaUf'),
#  SubnetInfo(netuid=111, rho=10, kappa=32767, difficulty=18446744073709551615, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=9, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.014060904, owner_ss58='5HKeYGvjWXKfB6VVtG4SBpRa87TyKYzc6n8pJKacStFwWyfZ'),
#  SubnetInfo(netuid=112, rho=10, kappa=32767, difficulty=18446744073709551615, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=10, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.000614944, owner_ss58='5D7Rf7HbeE7ti49fyLg3TM3F96uWFUwzYBo9SkzBpAUTQMhM'),
#  SubnetInfo(netuid=113, rho=10, kappa=32767, difficulty=18446744073709551615, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=240, max_n=256, blocks_since_epoch=11, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.000500000, owner_ss58='5Fsz3GWECNKqW1E1cZSoNsH9rgNXk6HG6NPPJtmVUYExnGDB'),
#  SubnetInfo(netuid=114, rho=10, kappa=32767, difficulty=18446744073709551615, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=12, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.000579253, owner_ss58='5HGk8WmSyauz4Ec2KGwUFmGjMB3USknptaE6wMXPx9vaACwf'),
#  SubnetInfo(netuid=115, rho=10, kappa=32767, difficulty=18446744073709551615, immunity_period=65535, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=13, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.000509911, owner_ss58='5H3nQjrwCKZGFuvP4iCQjs1sd5ge4JN9zu5kiD1WrSr2StpV'),
#  SubnetInfo(netuid=116, rho=10, kappa=32767, difficulty=18446744073709551615, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=14, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.000588075, owner_ss58='5GgjJXbcDyiGenKGfPrPhRxJ7p91EdC22fcAAF4ccbATgu6H'),
#  SubnetInfo(netuid=117, rho=10, kappa=32767, difficulty=18446744073709551615, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=15, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.000500000, owner_ss58='5Hg5g1gewtP9ibRF2AALhjjaVNvDBf1RwuA194xSD4WYTBrz'),
#  SubnetInfo(netuid=118, rho=10, kappa=32767, difficulty=18446744073709551615, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=16, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.000500000, owner_ss58='5H8Uhqp2K5vq8Y331DHcB3EchRJwb5ZBevpAFYEAZpQTg3b5'),
#  SubnetInfo(netuid=119, rho=10, kappa=32767, difficulty=18446744073709551615, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=17, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.000568568, owner_ss58='5DaHW3n1kpBxvj2Pc1sZDNkZMAsfRHhaABC38qpK5nBHWvQv'),
#  SubnetInfo(netuid=120, rho=10, kappa=32767, difficulty=18446744073709551615, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=18, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.364628765, owner_ss58='5Fc3ZZQAYB3SPXKcFnd1WJeyQvArSZZeB6LU1rb7zvQ6XvDh'),
#  SubnetInfo(netuid=121, rho=10, kappa=32767, difficulty=18446744073709551615, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=19, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.000808245, owner_ss58='5CXGaDJsffVeBK4CDhBNMVK6MH7fHbL7AbnjzZ8XP6QzFLWm'),
#  SubnetInfo(netuid=122, rho=10, kappa=32767, difficulty=18446744073709551615, immunity_period=10000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=20, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.038662855, owner_ss58='5H6fAdf7QsrZpLKyydA1pM9sxTK7qJx4S4jUgg6YMHr4Xzqs'),
#  SubnetInfo(netuid=123, rho=10, kappa=32767, difficulty=18446744073709551615, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=21, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.122598294, owner_ss58='5HVuEdEGMYisecwjkWC7dKDPEzgs9cECdsdCQagfPRVf6FxZ'),
#  SubnetInfo(netuid=124, rho=10, kappa=32767, difficulty=18446744073709551615, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=22, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.000500000, owner_ss58='5CB6igqihC83cq9jTujmgeGutQfzRrJjCQzcDizmYDYXvcVC'),
#  SubnetInfo(netuid=125, rho=10, kappa=32767, difficulty=18446744073709551615, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=23, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.001446664, owner_ss58='5DTzv2rL6YGQjCDNiWQJz2nE23fK1mDccH9eQimgiieyL3C4'),
#  SubnetInfo(netuid=126, rho=10, kappa=32767, difficulty=18446744073709551615, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=24, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.001255723, owner_ss58='5G6ZfGUQefzFD5V3vtc948n6SuQCczYe8tmuhMRsAwwCGitQ'),
#  SubnetInfo(netuid=127, rho=10, kappa=32767, difficulty=18446744073709551615, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=25, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.001030843, owner_ss58='5F9w7XojHP5DZE6MynArAeL9HgVZTuySZbxWDjKWhpLDQpU4'),
#  SubnetInfo(netuid=128, rho=10, kappa=32767, difficulty=18446744073709551615, immunity_period=5000, max_allowed_validators=64, min_allowed_weights=1, max_weight_limit=65535, scaling_law_power=50, subnetwork_n=256, max_n=256, blocks_since_epoch=26, tempo=360, modality=0, connection_requirements={}, emission_value=0, burn=τ0.000500000, owner_ss58='5GgMeLFN4YssT6f9i9pZpRmczt8GYDsCZ1nYPiGRcTPWn3AA')]
